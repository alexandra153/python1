# %%
#siempre lo que se hace es importar pandas y nunpy
import pandas as pd
import numpy as np

# %%
#ahora subimos el archivo desde google drive sin loguearnos
df_estudiantes=pd.read_csv('/content/drive/MyDrive/StudentsPerformance (1).csv')
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#sigamos con la creación de columnas usando assing o el metodo insert, si quiero agregar varias columnas uso assing y tambíen si quiero sobre escribir una columna

# %%
#Notas que se llena usando un arreglo de datos random almacenadas en variabless
filosofia_score=np.random.randint(1,100,size=1000)
fisica_score=np.random.randint(1,100,size=1000)

# %%
#se agrega un indice para cada fila
filosofia_nota=pd.Series(filosofia_score, index=np.arange(0,1000))
fisica_nota=pd.Series(fisica_score, index=np.arange(0,1000))

# %%
#se ponen las nuevas columnas a mi dataframe usando assing
df_estudiantes.assign(filosofia_score=filosofia_nota, fisica_score=fisica_nota)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_estudiantes=df_estudiantes.assign(filosofia_score=filosofia_nota, fisica_score=fisica_nota)
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#para usar el metodo insert este no me devuelve copias si no que el cambio queda guardado de inmediato
df_estudiantes.insert(1,"ED_SCORE", fisica_nota)

# %%
df_estudiantes
# Out:
#      gender  ED_SCORE race/ethnicity parental level of education  \
# 0    female        44        group B           bachelor's degree
# 1    female         7        group C                some college
# 2    female        23        group B             master's degree
# 3      male         4        group A          associate's degree
# 4      male        96        group C                some college
# ..      ...       ...            ...                         ...
# 995  female        74        group E             master's degree
# 996    male        31        group C                 high school
# 997  female        99        group C                 high school
# 998  female        35        group D                some college
# 999  female        52        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# ...
